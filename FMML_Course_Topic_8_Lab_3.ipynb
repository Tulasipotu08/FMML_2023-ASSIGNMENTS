# %% [markdown]
# <a href="https://colab.research.google.com/github/Tulasipotu08/FMML_2023-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-08 04:10:15--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   216MB/s    in 0.3s
#
# 2024-04-08 04:10:16 (216 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 9868   1604.05288v3  While probability theory is normally applied t...    cs
# 4366   1606.05589v1  We conduct large-scale studies on `human atten...  stat
# 16496  1703.03842v2  Exemplar models are a popular class of models ...    cs
# 15372   1410.2082v2  Word alignment is an important natural languag...    cs
# 15224  1612.05420v1  We propose a new approach for extracting argum...    cs
# ...             ...                                                ...   ...
# 22175  1506.05967v3  Nonparametric extension of tensor regression i...  stat
# 7491   1801.06309v1  Generative adversarial networks (GAN) have bec...  stat
# 29644  1710.00307v1  The Residual Networks of Residual Networks (Ro...    cs
# 22154  1506.02236v2  In this paper we propose a family of tractable...  stat
# 6050   1606.05596v1  It has been noticed that some external CVIs ex...  stat
#
#                                                    title  year  \
# 9868                                 Inductive Coherence  2016
# 4366   Human Attention in Visual Question Answering: ...  2016
# 16496  Effects of Limiting Memory Capacity on the Beh...  2017
# 15372  Contrastive Unsupervised Word Alignment with N...  2014
# 15224  A Two-Phase Approach Towards Identifying Argum...  2016
# ...                                                  ...   ...
# 22175  Doubly Decomposing Nonparametric Tensor Regres...  2015
# 7491   Composite Functional Gradient Learning of Gene...  2018
# 29644             Pyramidal RoR for Image Classification  2017
# 22154                       Generalized Spectral Kernels  2015
# 6050   Ground Truth Bias in External Cluster Validity...  2016
#
#                                                 keywords
# 9868   [probability, environments, probabilistic, com...
# 4366   [attention, answering, understand, questions, ...
# 16496  [individual, behaviour, particular, demonstrat...
# 15372  [alignment, important, processing, indicates, ...
# 15224  [extracting, structure, underlying, comprises,...
# ...                                                  ...
# 22175  [nonparametric, extension, regression, nonline...
# 7491   [generative, adversarial, generating, observat...
# 29644  [excellent, performance, classification, incre...
# 22154  [tractable, functions, approximate, arbitrary,...
# 6050   [preferential, monotonic, candidate, partition...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 9868     [probability, environments, probabilistic, com...
# 4366     [attention, answering, understand, questions, ...
# 16496    [individual, behaviour, particular, demonstrat...
# 15372    [alignment, important, processing, indicates, ...
# 15224    [extracting, structure, underlying, comprises,...
#                                ...
# 9896     [separation, important, applications, challeng...
# 36362    [emergence, technologies, appearance, applicat...
# 15597    [institute, technology, submission, translatio...
# 17723    [investigate, translation, audiobooks, specifi...
# 22036    [regularized, identification, covariance, info...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8723 words.
# Out of those 4527 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6e39417c-362c-4f2b-9b1a-a9dd5b219936" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e39417c-362c-4f2b-9b1a-a9dd5b219936")) {                    Plotly.newPlot(                        "6e39417c-362c-4f2b-9b1a-a9dd5b219936",                        [{"x":["integrating","constraints","algorithms","criterion","arithmetic","assigning","uncertainty","environments","significant","appropriate","probabilistic","algorithm","coherence","reasoning","approximations","introduce","perspective","satisfies","probability","distribution","expensive","computation","limitation","probabilities","computations","guarantees","distributions","mathematical","statements","inductive","annotation","interfaces","experiments","answering","questions","understand","quantitatively","qualitatively","generated","attention","particular","demonstrate","behaviour","simplified","extinction","investigate","addressed","categories","individual","simulations","knowledge","differentiate","processing","functions","observation","unsupervised","posterior","partition","divergence","concentrated","indicates","considerable","generative","introduces","efficient","capturing","correspondence","approximate","expectations","languages","calculation","challenge","improvements","important","contrastive","alignments","intractable","approaches","discriminative","calculate","alignment","comprises","embedding","outperforms","structure","baselines","prediction","identifying","underlying","argumentation","classifiers","relations","assignment","wikipedia","linguistic","extracting","effective","different","strategies","inference","autoregressive","confidence","asymptotically","procedure","estimators","decorrelation","martingale","collection","adaptively","dependence","collected","distributional","transforming","empirical","information","sequential","propensity","estimator","intervals","regression","solutions","observations","monitored","monitoring","interested","operating","background","surgeries","detecting","increased","detection","performance","improving","beginning","irrelevant","instrument","extremely","interacts","instruments","therefore","combining","recording","microscope","automated","disappear","observing","complexity","simulation","development","artificial","benchmark","programming","intelligence","simulated","competition","behavioural","dirichlet","assortativity","relatively","demonstrated","components","meaningful","allocation","alternative","community","interpretable","interaction","computationally","nonparametric","introduced","communities","component","structures","seriously","currently","motivated","implementation","applications","dimensional","illustrate","efficiently","hyperspectral","separable","automatically","nonnegative","mathematics","factorization","polynomial","requiring","available","vocabulary","sentiment","potential","additional","polarities","selection","unreliable","occasionally","prohibitive","constitute"],"y":[37,166,618,53,10,11,90,78,252,86,186,800,21,121,31,336,77,12,177,179,62,141,24,62,30,56,122,55,15,17,65,17,626,57,65,70,21,13,170,189,265,541,26,20,2,157,30,59,117,40,360,7,300,200,69,128,35,35,19,6,19,42,102,77,416,41,24,108,10,90,18,154,98,325,12,13,24,410,86,26,52,17,89,256,336,52,247,78,112,12,112,80,38,25,66,61,252,736,97,206,5,33,12,97,16,2,2,71,26,23,64,28,11,143,706,66,1,26,14,110,137,71,2,34,28,28,75,3,74,40,317,912,110,8,11,6,42,7,3,135,103,8,7,93,2,21,240,74,116,133,213,115,95,61,27,5,19,1,51,89,104,51,25,101,80,33,72,94,17,129,13,110,139,1,48,50,119,413,174,78,161,14,9,181,5,14,31,53,45,289,43,51,159,125,3,158,12,1,9,20],"type":"bar"},{"x":["integrating","constraints","algorithms","criterion","arithmetic","assigning","uncertainty","e ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4527,), (4527, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.82

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Object</span> <span style=''>Part</span> <span style='background-color:rgba(0, 255, 0, 0.41573033707865165);'>Attention</span> <span style=''>Model</span> <span style=''>for</span> <span style=''>Fine</span> <span style=''>grained</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <br/><br/><span style=''>Fine</span> <span style=''>grained</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.8723404255319148);'>recognize</span> <span style=''>hundreds</span> <span style=''>of</span> <span style=''>subcategories</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>belonging</span> <span style=''>to</span> <span style=''>the</span> <span style=''>same</span> <span style=''>basic</span> <span style=''>level</span> <span style=''>category</span> <span style=''>such</span> <span style=''>as</span> <span style=''>200</span> <span style=''>subcategories</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>belonging</span> <span style=''>to</span> <span style=''>the</span> <span style=''>bird</span> <span style=''>which</span> <span style=''>is</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.39178082191780816);'>challenging</span> <span style=''>due</span> <span style=''>to</span> <span style=''>large</span> <span style=''>variance</span> <span style=''>in</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>subcategory</span> <span style=''>and</span> <span style=''>small</span> <span style=''>variance</span> <span style=''>among</span> <span style='background-color:rgba(0, 255, 0, 0.32732191163210095);'>different</span> <span style=''>subcategories</span> <span style=''>Existing</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>first</span> <span style=''>locate</span> <span style=''>the</span> <span style=''>objects</span> <span style=''>or</span> <span style=''>parts</span> <span style=''>and</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminate</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>subcategory</span> <span style=''>the</span> <span style=''>image</span> <span style=''>belongs</span> <span style=''>to</span> <span style=''>However</span> <span style=''>they</span> <span style=''>mainly</span> <span style=''>have</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>limitations</span> <span style=''>(1)</span> <span style=''>Relying</span> <span style=''>on</span> <span style=''>object</span> <span style=''>or</span> <span style=''>part</span> <span style='background-color:rgba(0, 255, 0, 0.84375);'>annotations</span> <span style=''>which</span> <span style=''>are</span> <span style=''>heavily</span> <span style=''>labor</span> <span style='background-color:rgba(0, 255, 0, 0.3103448275862069);'>consuming</span> <span style=''>(2)</span> <span style=''>Ignoring</span> <span style=''>the</span> <span style=''>spatial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>the</span> <span style=''>object</span> <span style=''>and</span> <span style=''>its</span> <span style=''>parts</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>among</span> <span style=''>these</span> <span style=''>parts</span> <span style=''>both</span> <span style=''>of</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style=''>helpful</span> <span style=''>for</span> <span style=''>finding</span> <span style='background-colo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>with</span> <span style=''>Local</span> <span style=''>Spatial</span> <span style=''>and</span> <span style=''>Temporal</span> <span style=''>Changes</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>cost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>change</span> <span style=''>over</span> <span style=''>time</span> <span style=''>under</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style=''>budget</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>L</span> <span style=''>pq</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>to</span> <span style=''>quantify</span> <span style=''>the</span> <span style=''>change</span> <span style=''>which</span> <span style=''>captures</span> <span style=''>local</span> <span style=''>spatial</span> <span style=''>and</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>Under</span> <span style=''>the</span> <span style=''>L</span> <span style=''>pq</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>both</span> <span style=''>upper</span> <span style=''>and</span> <span style=''>matching</span> <span style=''>lower</span> <span style=''>regret</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>smooth</span> <span style=''>and</span> <span style=''>strongly</span> <span style=''>convex</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>previous</span> <span style=''>results</span> <span style=''>in</span> <span style=''>(Besbes</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2015)</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>reveal</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surprising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>phenomena</span> <span style=''>under</span> <span style=''>this</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>curse</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Random</span> <span style=''>Utility</span> <span style=''>Theory</span> <span style=''>for</span> <span style=''>Social</span> <span style=''>Choice</span> <br/><br/><span style=''>Random</span> <span style=''>utility</span> <span style=''>theory</span> <span style=''>models</span> <span style=''>an</span> <span style=''>agents</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preferences</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternatives</span> <span style=''>by</span> <span style=''>drawing</span> <span style=''>a</span> <span style=''>real</span> <span style=''>valued</span> <span style=''>score</span> <span style=''>on</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>(typically</span> <span style=''>independently)</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameterized</span> <span style='background-color:rgba(255, 0, 0, 0.35262206148282105);'>distribution</span> <span style=''>and</span> <span style=''>then</span> <span style=''>ranking</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternatives</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>according</span> <span style=''>to</span> <span style=''>scores</span> <span style=''>A</span> <span style=''>special</span> <span style=''>case</span> <span style=''>that</span> <span style=''>has</span> <span style=''>received</span> <span style='background-color:rgba(0, 255, 0, 0.33687002652519893);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.41573033707865165);'>attention</span> <span style=''>is</span> <span style=''>the</span> <span style=''>Plackett</span> <span style=''>Luce</span> <span style=''>model</span> <span style=''>for</span> <span style=''>which</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.32125205930807255);'>inference</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.517241379310345);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.6444444444444444);'>estimators</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>develops</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>on</span> <span style=''>general</span> <span style=''>random</span> <span style=''>utility</span> <span style=''>models</span> <span style=''>that</span> <span style=''>enable</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.32125205930807255);'>inference</span> <span style=''>within</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>through</span> <span style=''>MC</span> <span style=''>EM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>providing</span> <span style=''>concave</span> <span style=''>loglikelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>bounded</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>global</span> <span style=''>maxima</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>Results</span> <span style=''>on</span> <span style=''>both</span> <span style=''>real</span> <span style=''>world</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.351063829787234);'>simulated</span> <span style=''>data</span> <span style=''>provide</span> <span style=''>support</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scalability</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Tree</span> <span style=''>Space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prototypes</span> <span style=''>Another</span> <span style=''>Look</span> <span style=''>at</span> <span style=''>Making</span> <span style=''>Tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Ensembles</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretable</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Ensembles</span> <span style=''>of</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>have</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>accuracy</span> <span style=''>but</span> <span style=''>suffer</span> <span style=''>from</span> <span style=''>a</span> <span style=''>lack</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreting</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style=''>by</span> <span style=''>finding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prototypes</span> <span style=''>in</span> <span style=''>tree</span> <span style=''>space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utilizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>learned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>measure</span> <span style=''>from</span> <span style=''>the</span> <span style=''>tree</span> <span style=''>ensemble</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Demonstrating</span> <span style=''>the</span> <span style=''>method</span> <span style=''>on</span> <span style=''>random</span> <span style=''>forests</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>method</span> <span style=''>benefits</span> <span style=''>from</span> <span style=''>unique</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style=''>tree</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequentially</span> <span style=''>find</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prototypes</span> <span style=''>The</span> <span style=''>method</span> <span style=''>provides</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>accuracy</span> <span style=''>when</span> <span style=''>found</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prototypes</span> <span style=''>are</span> <span style=''>used</span> <span style=''>in</span> <span style=''>nearest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prototype</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>while</span> <span style=''>using</span> <span style=''>fewer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prototypes</span> <span style=''>than</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitor</span> <span style=''>methods</span> <span style=''>We</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitivity</span> <span style=''>of</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1288936627282492)
# 	processing (0.10741138560687433)
# 	representation (0.12996777658431793)
# 	detection (0.11349803079126387)
# 	segmentation (0.07590404582885786)
# 	architecture (0.09129967776584318)
# 	information (0.2527747941281776)
# 	different (0.26351593268886503)
# 	convolutional (0.13712853562477623)
# 	recognition (0.13569638381668456)
#
# Some Statistics words are:
# 	variables (0.13552566018933732)
# 	stochastic (0.13652217239661185)
# 	theoretical (0.14997508719481814)
# 	statistical (0.15495764823119082)
# 	estimation (0.17339312406576982)
# 	dimensional (0.1783756851021425)
# 	algorithm (0.40408570004982564)
# 	distribution (0.1863477827603388)
# 	inference (0.1998006975585451)
# 	regression (0.1878425510712506)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1b325c13-dfeb-484a-99f8-9a72686ee73b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b325c13-dfeb-484a-99f8-9a72686ee73b")) {                    Plotly.newPlot(                        "1b325c13-dfeb-484a-99f8-9a72686ee73b",                        [{"x":["integrating","constraints","algorithms","criterion","arithmetic","assigning","uncertainty","environments","significant","appropriate","probabilistic","algorithm","coherence","reasoning","approximations","introduce","perspective","satisfies","probability","distribution","expensive","computation","limitation","probabilities","computations","guarantees","distributions","mathematical","statements","inductive","annotation","interfaces","experiments","answering","questions","understand","quantitatively","qualitatively","generated","attention","particular","demonstrate","behaviour","simplified","extinction","investigate","addressed","categories","individual","simulations","knowledge","differentiate","processing","functions","observation","unsupervised","posterior","partition","divergence","concentrated","indicates","considerable","generative","introduces","efficient","capturing","correspondence","approximate","expectations","languages","calculation","challenge","improvements","important","contrastive","alignments","intractable","approaches","discriminative","calculate","alignment","comprises","embedding","outperforms","structure","baselines","prediction","identifying","underlying","argumentation","classifiers","relations","assignment","wikipedia","linguistic","extracting","effective","different","strategies","inference","autoregressive","confidence","asymptotically","procedure","estimators","decorrelation","martingale","collection","adaptively","dependence","collected","distributional","transforming","empirical","information","sequential","propensity","estimator","intervals","regression","solutions","observations","monitored","monitoring","interested","operating","background","surgeries","detecting","increased","detection","performance","improving","beginning","irrelevant","instrument","extremely","interacts","instruments","therefore","combining","recording","microscope","automated","disappear","observing","complexity","simulation","development","artificial","benchmark","programming","intelligence","simulated","competition","behavioural","dirichlet","assortativity","relatively","demonstrated","components","meaningful","allocation","alternative","community","interpretable","interaction","computationally","nonparametric","introduced","communities","component","structures","seriously","currently","motivated","implementation","applications","dimensional","illustrate","efficiently","hyperspectral","separable","automatically","nonnegative","mathematics","factorization","polynomial","requiring","available","vocabulary","sentiment","potential","additional","polarities","selection","unreliable","occasionally","prohibitive","constitute","incrementally","incremental","opinionated","documents","assumption","challenges","continuous","unlabeled","requesting","exploiting","classifier","difficulty","experimentally","containing","variables","difficult","technique","practitioner","selecting","minimisation","textitforward","architectures","effectiveness","consistent","conventional","regularization","differently","benchmarks","recurrent","implement","connections","interplay","suggested","recognition","promising","comprehensive","computational","including","architecture","operation","investigated","characterizing","convolution","convolutional","operations","variations","affective","conditions","behavioral","quantitative","progression","temporally","understanding","splitting","optimization","res ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	unraveling
# 	diagonalise
# 	colorectal
# 	regularizations
# 	parametrization
# 	misspecification
# 	isometric
# 	submanifold
# 	inductively
# 	framelets
# 	barycenters
# 	incrementalonline
# 	coincides
# 	integrator
# 	thermostat
# 	integrators
# 	astrophysics
# 	misspecified
# 	integrand
# 	integrands
# Some words which never appear in Statistics papers:
# 	extinction
# 	argumentation
# 	monitored
# 	surgeries
# 	microscope
# 	disappear
# 	opinionated
# 	requesting
# 	affective
# 	precursor
# 	populating
# 	logically
# 	predicates
# 	fragments
# 	integrity
# 	authenticity
# 	coreference
# 	devanagari
# 	displacement
# 	communicative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0809994762300896e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7858333333333334
